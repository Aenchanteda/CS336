# %%
# 安装 wandb（如果未安装）
import sys
import subprocess

try:
    import wandb
    print("wandb 已安装")
except ImportError:
    print("正在安装 wandb...")
    subprocess.check_call([sys.executable, "-m", "pip", "install", "wandb"])
    import wandb
    print("wandb 安装完成！")

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting wandb
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/12/0b/c3d7053dfd93fd259a63c7818d9c4ac2ba0642ff8dc8db98662ea0cf9cc0/wandb-0.23.1-py3-none-macosx_12_0_arm64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 4.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: click>=8.0.1 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (8.1.7)
# Collecting eval-type-backport (from wandb)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/cf/22/fdc2e30d43ff853720042fa15baa3e6122722be1a7950a98233ebb55cd71/eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl (208 kB)
# Requirement already satisfied: packaging in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (25.0)
# Requirement already satisfied: platformdirs in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (5.29.5)
# Collecting pydantic<3 (from wandb)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f4/3c/8cc1cc84deffa6e25d2d0c688ebb80635dfdbf1dbea3e30c541c8cf4d860/pydantic-2.10.6-py3-none-any.whl (431 kB)
# Requirement already satisfied: pyyaml in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (6.0.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (2.32.4)
# Collecting sentry-sdk>=2.0.0 (from wandb)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/4d/19/8d77f9992e5cbfcaa9133c3bf63b4fbbb051248802e1e803fed5c552fbb2/sentry_sdk-2.48.0-py2.py3-none-any.whl (414 kB)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from wandb) (4.12.2)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/a0/61/5c78b91c3143ed5c14207f463aecfc8f9dbb5092fb2869baf37c273b2705/gitdb-4.0.12-py3-none-any.whl (62 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3->wandb)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/78/b6/6307fbef88d9b5ee7421e68d78a9f162e0da4900bc5f5793f6d3d0e34fb8/annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.27.2 (from pydantic<3->wandb)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/f4/20/26c549249769ed84877f862f7bb93f89a6ee08b4bee1ed8781616b7fbb5e/pydantic_core-2.27.2-cp38-cp38-macosx_11_0_arm64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/richard/opt/anaconda3/envs/deepDR/OneRel_chinese/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/04/be/d09147ad1ec7934636ad912901c5fd7667e1c858e19d355237db0d0cd5e4/smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, sentry-sdk, pydantic-core, eval-type-backport, annotated-types, pydantic, gitdb, gitpython, wandb
# Successfully installed annotated-types-0.7.0 eval-type-backport-0.3.1 gitdb-4.0.12 gitpython-3.1.45 pydantic-2.10.6 pydantic-core-2.27.2 sentry-sdk-2.48.0 smmap-5.0.2 wandb-0.23.1

# %%
import random  # for demo script
import wandb

wandb.login()

epochs = 10
lr = 0.01

run = wandb.init(
    # Set the project where this run will be logged
    project="my-awesome-project",
    # Track hyperparameters and run metadata
    config={
        "learning_rate": lr,
        "epochs": epochs,
    },
)

offset = random.random() / 5
print(f"lr: {lr}")

# simulating a training run
for epoch in range(2, epochs):
    acc = 1 - 2**-epoch - random.random() / epoch - offset
    loss = 2**-epoch + random.random() / epoch + offset
    print(f"epoch={epoch}, accuracy={acc}, loss={loss}")
    wandb.log({"accuracy": acc, "loss": loss})
# Out:
# wandb: Currently logged in as: northwest_nan (northwest_nan-peking-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/Users/richard/Documents/GitHub/assignment1-basics/cs336_basics/wandb/run-20251230_133308-rhyjim7s</code>
# Syncing run <strong><a href='https://wandb.ai/northwest_nan-peking-university/my-awesome-project/runs/rhyjim7s' target="_blank">easy-capybara-1</a></strong> to <a href='https://wandb.ai/northwest_nan-peking-university/my-awesome-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/northwest_nan-peking-university/my-awesome-project' target="_blank">https://wandb.ai/northwest_nan-peking-university/my-awesome-project</a>
#  View run at <a href='https://wandb.ai/northwest_nan-peking-university/my-awesome-project/runs/rhyjim7s' target="_blank">https://wandb.ai/northwest_nan-peking-university/my-awesome-project/runs/rhyjim7s</a>
# lr: 0.01
# epoch=2, accuracy=0.4092708606953371, loss=0.3288455099671234
# epoch=3, accuracy=0.536756241687971, loss=0.28665710723400734
# epoch=4, accuracy=0.8530657503765899, loss=0.29990619128791296
# epoch=5, accuracy=0.7984707716427708, loss=0.14799306304626164
# epoch=6, accuracy=0.8735583298420162, loss=0.1766578149222603
# epoch=7, accuracy=0.811328309228091, loss=0.20118582637433088
# epoch=8, accuracy=0.8700977462077978, loss=0.11952541641881624
# epoch=9, accuracy=0.9397356856928709, loss=0.08019062657620799
